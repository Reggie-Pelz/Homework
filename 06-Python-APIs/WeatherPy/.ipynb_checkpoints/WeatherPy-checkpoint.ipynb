# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#test changes

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

#test_cities = cities[:5]
#print(test_cities)
# Out:
# 609

# %%
#create data frame
cities_df = pd.DataFrame()
cities_df['City'] = ''
cities_df['Lat'] = ''
cities_df['Lng'] = ''
cities_df['Max Temp'] = ''
cities_df['Humidity'] = ''
cities_df['Cloudiness'] = ''
cities_df['Wind Speed'] = ''
cities_df['Country'] = ''

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

#city = 'anaheim'

for city in cities:
    query_url = url + 'appid=' + weather_api_key + '&q=' + city + '&units=imperial'
    weather_response = requests.get(query_url).json()

    try:
        city_index = cities.index(city) + 1
        city_name = weather_response['name']
        
        print(f'Retrieving result {city_index} for city name:{city_name}')
        
        cities_df.loc[city, 'City'] = city_name
        cities_df.loc[city, 'Lat'] = weather_response['coord']['lat']
        cities_df.loc[city, 'Lng'] = weather_response['coord']['lon'] 
        cities_df.loc[city, 'Max Temp'] = weather_response['main']['temp_max']
        cities_df.loc[city, 'Humidity'] = weather_response['main']['humidity']
        cities_df.loc[city, 'Cloudiness'] = weather_response['clouds']['all']
        cities_df.loc[city, 'Wind Speed'] = weather_response['wind']['speed']
        cities_df.loc[city, 'Country'] = weather_response['sys']['country']
    except (KeyError, IndexError):
        print('Missing info')
        
        
#print(query_url)
#weather_response
# Out:
# Retrieving result 1 for city name:Kloulklubed
# Retrieving result 2 for city name:Busselton
# Retrieving result 3 for city name:Namangan
# Retrieving result 4 for city name:Rikitea
# Retrieving result 5 for city name:Bredasdorp
# Retrieving result 6 for city name:Albany
# Retrieving result 7 for city name:Saint-Philippe
# Retrieving result 8 for city name:Muroto-misakicho
# Retrieving result 9 for city name:Norman Wells
# Retrieving result 10 for city name:Cape Town
# Missing info
# Retrieving result 12 for city name:Mataura
# Retrieving result 13 for city name:Parabel'
# Retrieving result 14 for city name:Hambantota
# Retrieving result 15 for city name:Ushuaia
# Retrieving result 16 for city name:Ahipara
# Retrieving result 17 for city name:Hillsborough
# Retrieving result 18 for city name:Lavrentiya
# Retrieving result 19 for city name:Narsaq
# Retrieving result 20 for city name:Half Moon Bay
# Retrieving result 21 for city name:Puerto Carreño
# Retrieving result 22 for city name:Balkanabat
# Retrieving result 23 for city name:North Bend
# Retrieving result 24 for city name:Plettenberg Bay
# Retrieving result 25 for city name:Puerto Ayora
# Retrieving result 26 for city name:New Norfolk
# Retrieving result 27 for city name:Port Alfred
# Retrieving result 28 for city name:Kahului
# Retrieving result 29 for city name:Port Shepstone
# Retrieving result 30 for city name:Rawtenstall
# Retrieving result 31 for city name:Vaini
# Retrieving result 32 for city name:Caravelas
# Retrieving result 33 for city name:Saldanha
# Retrieving result 34 for city name:Chokurdakh
# Missing info
# Retrieving result 36 for city name:Hobart
# Missing info
# Retrieving result 38 for city name:Ribeira Grande
# Retrieving result 39 for city name:Severo-Kuril'sk
# Retrieving result 40 for city name:Aransas Pass
# Retrieving result 41 for city name:Kavaratti
# Retrieving result 42 for city name:Fairbanks
# Retrieving result 43 for city name:Bogorodskoye
# Retrieving result 44 for city name:Puerto Ayacucho
# Retrieving result 45 for city name:Saint Paul Harbor
# Retrieving result 46 for city name:Punta Arenas
# Retrieving result 47 for city name:Wanaka
# Retrieving result 48 for city name:Maryville
# Missing info
# Missing info
# Retrieving result 51 for city name:Kologriv
# Retrieving result 52 for city name:Tuktoyaktuk
# Retrieving result 53 for city name:Cidreira
# Retrieving result 54 for city name:Upernavik
# Retrieving result 55 for city name:Bluff
# Retrieving result 56 for city name:Miracatu
# Retrieving result 57 for city name:Iquitos
# Retrieving result 58 for city name:Atuona
# Retrieving result 59 for city name:Orai
# Retrieving result 60 for city name:Teguise
# Retrieving result 61 for city name:Cherskiy
# Retrieving result 62 for city name:Lucapa
# Retrieving result 63 for city name:Ilulissat
# Retrieving result 64 for city name:Bambous Virieux
# Retrieving result 65 for city name:Chui
# Retrieving result 66 for city name:Pevek
# Retrieving result 67 for city name:Gizo Government Station
# Retrieving result 68 for city name:Lata
# Retrieving result 69 for city name:Qaanaaq
# Retrieving result 70 for city name:Mossamedes
# Retrieving result 71 for city name:Nome
# Missing info
# Retrieving result 73 for city name:Katobu
# Retrieving result 74 for city name:Dikson
# Retrieving result 75 for city name:Zhangaözen
# Retrieving result 76 for city name:Marabu
# Retrieving result 77 for city name:Hilo
# Retrieving result 78 for city name:Arraial do Cabo
# Retrieving result 79 for city name:Barrow
# Retrieving result 80 for city name:Biltine
# Retrieving result 81 for city name:Cabra
# Retrieving result 82 for city name:Sambava
# Retrieving result 83 for city name:Lebu
# Retrieving result 84 for city name:Bambanglipuro
# Retrieving result 85 for city name:Herzberg
# Retrieving result 86 for city name:Qian’an
# Retrieving result 87 for city name:Avarua
# Retrieving result 88 for city name:Nanortalik
# Retrieving result 89 for city name:Mehamn
# Retrieving result 90 for city name:Provideniya
# Missing info
# Retrieving result 92 for city name:Jamestown
# Retrieving result 93 for city name:Bilibino
# Retrieving result 94 for city name:Kabanjahe
# Retrieving result 95 for city name:Tasiilaq
# Retrieving result 96 for city name:Kapaa
# Retrieving result 97 for city name:Henties Bay
# Retrieving result 98 for city name:Lüderitz
# Retrieving result 99 for city name:Alofi
# Retrieving result 100 for city name:Uusikaupunki
# Retrieving result 101 for city name:Dayong
# Retrieving result 102 for city name:Faya
# Retrieving result 103 for city name:Royan
# Retrieving result 104 for city name:Pitimbu
# Retrieving result 105 for city name:Saint Anthony
# Retrieving result 106 for city name:Ciudad del Carmen
# Retrieving result 107 for city name:Noyabrsk
# Retrieving result 108 for city name:Road Town
# Retrieving result 109 for city name:General Roca
# Retrieving result 110 for city name:Hay River
# Retrieving result 111 for city name:Husavik
# Retrieving result 112 for city name:Berlevåg
# Retrieving result 113 for city name:Iqaluit
# Retrieving result 114 for city name:Ciudad Bolivar
# Retrieving result 115 for city name:Bethel
# Retrieving result 116 for city name:Yangi Marg`ilon
# Retrieving result 117 for city name:Takoradze
# Missing info
# Retrieving result 119 for city name:Huarmey
# Retrieving result 120 for city name:Pervomayskiy
# Retrieving result 121 for city name:Kumul
# Retrieving result 122 for city name:Margate
# Retrieving result 123 for city name:Gamba
# Missing info
# Retrieving result 125 for city name:Portales
# Retrieving result 126 for city name:Pueblo
# Retrieving result 127 for city name:Colombo
# Retrieving result 128 for city name:Ponta do Sol
# Retrieving result 129 for city name:Ndungu
# Retrieving result 130 for city name:Esperance
# Retrieving result 131 for city name:East London
# Retrieving result 132 for city name:Butaritari
# Retrieving result 133 for city name:Havelock
# Retrieving result 134 for city name:Sitka
# Retrieving result 135 for city name:Northam
# Retrieving result 136 for city name:Kamenka
# Retrieving result 137 for city name:Tura
# Retrieving result 138 for city name:Jinchang
# Retrieving result 139 for city name:Mahébourg
# Retrieving result 140 for city name:Koungou
# Retrieving result 141 for city name:Hermanus
# Retrieving result 142 for city name:Inndyr
# Retrieving result 143 for city name:Khatanga
# Retrieving result 144 for city name:Nelson Bay
# Retrieving result 145 for city name:Guánica
# Retrieving result 146 for city name:Boa Vista
# Retrieving result 147 for city name:Tiksi
# Retrieving result 148 for city name:Airai
# Retrieving result 149 for city name:Sisimiut
# Retrieving result 150 for city name:Alta Floresta
# Retrieving result 151 for city name:Klaksvík
# Retrieving result 152 for city name:Raudeberg
# Retrieving result 153 for city name:Port Elizabeth
# Retrieving result 154 for city name:Dwārka
# Retrieving result 155 for city name:Ucluelet
# Retrieving result 156 for city name:Souillac
# Retrieving result 157 for city name:Tessalit
# Retrieving result 158 for city name:Tabou
# Retrieving result 159 for city name:Thenzawl
# Retrieving result 160 for city name:Chānasma
# Missing info
# Retrieving result 162 for city name:Santo Antônio do Sudoeste
# Retrieving result 163 for city name:Noumea
# Retrieving result 164 for city name:Warri
# Retrieving result 165 for city name:Great Bend
# Retrieving result 166 for city name:Vardø
# Retrieving result 167 for city name:Calvinia
# Retrieving result 168 for city name:Gorontalo
# Missing info
# Retrieving result 170 for city name:Fortuna
# Retrieving result 171 for city name:Bubaque
# Retrieving result 172 for city name:Mar del Plata
# Retrieving result 173 for city name:Carnarvon
# Retrieving result 174 for city name:Kangaatsiaq
# Missing info
# Retrieving result 176 for city name:Saint George
# Retrieving result 177 for city name:Praia da Vitória
# Retrieving result 178 for city name:Aklavik
# Retrieving result 179 for city name:Hirara
# Missing info
# Retrieving result 181 for city name:Hithadhoo
# Retrieving result 182 for city name:Kishanganj
# Retrieving result 183 for city name:Assiut
# Retrieving result 184 for city name:Yerbogachën
# Retrieving result 185 for city name:Veracruz
# Retrieving result 186 for city name:Geraldton
# Retrieving result 187 for city name:Kidal
# Retrieving result 188 for city name:Kropotkin
# Retrieving result 189 for city name:Port-Cartier
# Retrieving result 190 for city name:Mogadishu
# Retrieving result 191 for city name:Hamilton
# Retrieving result 192 for city name:Izhma
# Retrieving result 193 for city name:Prome
# Retrieving result 194 for city name:Setúbal
# Retrieving result 195 for city name:Cabo San Lucas
# Retrieving result 196 for city name:Zhalantun
# Retrieving result 197 for city name:Banda Aceh
# Retrieving result 198 for city name:Kudahuvadhoo
# Retrieving result 199 for city name:Zemen
# Retrieving result 200 for city name:Lufilufi
# Retrieving result 201 for city name:Shorewood
# Retrieving result 202 for city name:Otukpo
# Retrieving result 203 for city name:Dhār
# Retrieving result 204 for city name:Kaeo
# Retrieving result 205 for city name:Kemijärvi
# Retrieving result 206 for city name:Kimbe
# Retrieving result 207 for city name:Vila Franca do Campo
# Retrieving result 208 for city name:Engenheiro Beltrão
# Retrieving result 209 for city name:Abū Zabad
# Retrieving result 210 for city name:Shakiso
# Retrieving result 211 for city name:Furano
# Missing info
# Retrieving result 213 for city name:Tuatapere
# Retrieving result 214 for city name:Svetlaya
# Retrieving result 215 for city name:Saint-François
# Retrieving result 216 for city name:Constitución
# Retrieving result 217 for city name:Kuvshinovo
# Retrieving result 218 for city name:Nikolskoye
# Retrieving result 219 for city name:Isangel
# Retrieving result 220 for city name:Turukhansk
# Retrieving result 221 for city name:Castro
# Retrieving result 222 for city name:Jalu
# Retrieving result 223 for city name:Leningradskiy
# Retrieving result 224 for city name:Nisko
# Retrieving result 225 for city name:Bar Harbor
# Retrieving result 226 for city name:College
# Retrieving result 227 for city name:Bontang
# Retrieving result 228 for city name:Lokosovo
# Retrieving result 229 for city name:Soe
# Retrieving result 230 for city name:Padang
# Retrieving result 231 for city name:Wucheng
# Retrieving result 232 for city name:Mayo
# Missing info
# Missing info
# Retrieving result 235 for city name:Broome
# Retrieving result 236 for city name:Bodden Town
# Retrieving result 237 for city name:Broken Hill
# Missing info
# Retrieving result 239 for city name:Mudu
# Retrieving result 240 for city name:Rustam
# Retrieving result 241 for city name:Perelyub
# Retrieving result 242 for city name:Kalaisan
# Retrieving result 243 for city name:Bonthe
# Retrieving result 244 for city name:Saskylakh
# Retrieving result 245 for city name:Misratah
# Retrieving result 246 for city name:Te Anau
# Missing info
# Retrieving result 248 for city name:Pacanga
# Retrieving result 249 for city name:Alexandria
# Retrieving result 250 for city name:Saint-Pierre
# Retrieving result 251 for city name:George Town
# Retrieving result 252 for city name:Sur
# Retrieving result 253 for city name:Naze
# Retrieving result 254 for city name:Conceição da Barra
# Retrieving result 255 for city name:Pokrovskoye
# Missing info
# Retrieving result 257 for city name:San Pedro de Macorís
# Retrieving result 258 for city name:Loja
# Retrieving result 259 for city name:Clyde River
# Retrieving result 260 for city name:Tongren
# Retrieving result 261 for city name:Kruisfontein
# Retrieving result 262 for city name:Bonavista
# Retrieving result 263 for city name:Emerald
# Missing info
# Retrieving result 265 for city name:Igrim
# Retrieving result 266 for city name:Ishigaki
# Retrieving result 267 for city name:Salinópolis
# Retrieving result 268 for city name:Morgan City
# Retrieving result 269 for city name:San Luis
# Retrieving result 270 for city name:Līvāni
# Retrieving result 271 for city name:Luhyny
# Retrieving result 272 for city name:Puerto Suárez
# Retrieving result 273 for city name:Svobodnyy
# Retrieving result 274 for city name:Torbay
# Retrieving result 275 for city name:Siddipet
# Retrieving result 276 for city name:Roald
# Retrieving result 277 for city name:Khandyga
# Retrieving result 278 for city name:Jumla
# Retrieving result 279 for city name:Yumen
# Retrieving result 280 for city name:Bandarbeyla
# Retrieving result 281 for city name:Saint-Augustin
# Retrieving result 282 for city name:Longyearbyen
# Retrieving result 283 for city name:Sabha
# Retrieving result 284 for city name:Gohāna
# Retrieving result 285 for city name:Polis
# Retrieving result 286 for city name:Marsá Maţrūḩ
# Retrieving result 287 for city name:Garh Maharaja
# Retrieving result 288 for city name:Lloydminster
# Retrieving result 289 for city name:Dingli
# Retrieving result 290 for city name:Puerto Peñasco
# Retrieving result 291 for city name:Arles
# Retrieving result 292 for city name:Thompson
# Retrieving result 293 for city name:Yatou
# Retrieving result 294 for city name:Bengkulu
# Retrieving result 295 for city name:Kirkby in Ashfield
# Retrieving result 296 for city name:Baracoa
# Retrieving result 297 for city name:Olavarría
# Retrieving result 298 for city name:Lagos
# Retrieving result 299 for city name:Palmer
# Retrieving result 300 for city name:Dingle
# Missing info
# Missing info
# Retrieving result 303 for city name:Oil City
# Retrieving result 304 for city name:Panabá
# Retrieving result 305 for city name:Meulaboh
# Retrieving result 306 for city name:Mount Gambier
# Retrieving result 307 for city name:Phek
# Retrieving result 308 for city name:Troitsko-Pechorsk
# Retrieving result 309 for city name:Sørland
# Retrieving result 310 for city name:Inuvik
# Retrieving result 311 for city name:Kavieng
# Retrieving result 312 for city name:Sorong
# Retrieving result 313 for city name:El Ejido
# Retrieving result 314 for city name:Segezha
# Missing info
# Retrieving result 316 for city name:Pringsewu
# Retrieving result 317 for city name:Tiquicheo
# Retrieving result 318 for city name:Talnakh
# Retrieving result 319 for city name:Los Llanos de Aridane
# Retrieving result 320 for city name:Beringovskiy
# Retrieving result 321 for city name:Juegang
# Retrieving result 322 for city name:Guerrero Negro
# Retrieving result 323 for city name:Yagodnoye
# Retrieving result 324 for city name:Westport
# Retrieving result 325 for city name:Araouane
# Retrieving result 326 for city name:Maceió
# Retrieving result 327 for city name:Vikhorevka
# Retrieving result 328 for city name:Catió
# Retrieving result 329 for city name:Ailigandí
# Retrieving result 330 for city name:Zverinogolovskoye
# Missing info
# Retrieving result 332 for city name:Ribeira Brava
# Retrieving result 333 for city name:Hoopstad
# Missing info
# Retrieving result 335 for city name:Berezniki
# Retrieving result 336 for city name:Xinzhou
# Retrieving result 337 for city name:Sioux Lookout
# Retrieving result 338 for city name:Rupert
# Retrieving result 339 for city name:Kunming
# Retrieving result 340 for city name:Kindu
# Retrieving result 341 for city name:Kununurra
# Missing info
# Retrieving result 343 for city name:Champerico
# Retrieving result 344 for city name:Faanui
# Retrieving result 345 for city name:Al Bardīyah
# Retrieving result 346 for city name:Kargil
# Retrieving result 347 for city name:Salina
# Retrieving result 348 for city name:Surab
# Retrieving result 349 for city name:Sistranda
# Retrieving result 350 for city name:Lompoc
# Retrieving result 351 for city name:Erzin
# Retrieving result 352 for city name:Hobyo
# Retrieving result 353 for city name:Lengshuijiang
# Retrieving result 354 for city name:São Borja
# Retrieving result 355 for city name:Whitehorse
# Retrieving result 356 for city name:Peniche
# Retrieving result 357 for city name:Lixouri
# Retrieving result 358 for city name:Deputatsky
# Retrieving result 359 for city name:Touros
# Retrieving result 360 for city name:Maniitsoq
# Retrieving result 361 for city name:Laurel
# Missing info
# Retrieving result 363 for city name:Bagan
# Retrieving result 364 for city name:Tautira
# Retrieving result 365 for city name:Severnyy
# Retrieving result 366 for city name:Marawi
# Retrieving result 367 for city name:Grindavik
# Retrieving result 368 for city name:Vredendal
# Missing info
# Retrieving result 370 for city name:Kanniyākumāri
# Retrieving result 371 for city name:Sladkovo
# Retrieving result 372 for city name:Manokwari
# Retrieving result 373 for city name:Mangaratiba
# Retrieving result 374 for city name:Atar
# Retrieving result 375 for city name:Ukiah
# Retrieving result 376 for city name:Mikhaylovka
# Retrieving result 377 for city name:Kandrian
# Retrieving result 378 for city name:Tra Vinh
# Retrieving result 379 for city name:Itoman
# Retrieving result 380 for city name:Huntingdon
# Retrieving result 381 for city name:Nipawin
# Retrieving result 382 for city name:Saravena
# Retrieving result 383 for city name:Kaitangata
# Retrieving result 384 for city name:Yambio
# Retrieving result 385 for city name:Kailua
# Retrieving result 386 for city name:Khatauli
# Retrieving result 387 for city name:Pisco
# Retrieving result 388 for city name:Katsuura
# Missing info
# Retrieving result 390 for city name:Byron Bay
# Retrieving result 391 for city name:Codrington
# Retrieving result 392 for city name:Ol'ga
# Retrieving result 393 for city name:Barra de Tecoanapa
# Retrieving result 394 for city name:Saint-Louis
# Retrieving result 395 for city name:Linkou
# Retrieving result 396 for city name:Bathurst
# Retrieving result 397 for city name:Poum
# Retrieving result 398 for city name:Ancud
# Retrieving result 399 for city name:Yar-Sale
# Retrieving result 400 for city name:Upata
# Retrieving result 401 for city name:Key West
# Retrieving result 402 for city name:Guantánamo
# Missing info
# Retrieving result 404 for city name:Pingliang
# Missing info
# Retrieving result 406 for city name:Arriaga
# Retrieving result 407 for city name:Moerai
# Missing info
# Retrieving result 409 for city name:Cap-aux-Meules
# Retrieving result 410 for city name:Portland
# Retrieving result 411 for city name:Samthar
# Missing info
# Retrieving result 413 for city name:Bhānpura
# Retrieving result 414 for city name:Harper
# Retrieving result 415 for city name:Marquard
# Retrieving result 416 for city name:Cabedelo
# Retrieving result 417 for city name:Parintins
# Retrieving result 418 for city name:Hanmer Springs
# Retrieving result 419 for city name:Qinhuangdao
# Retrieving result 420 for city name:Narrabri
# Retrieving result 421 for city name:Iquique
# Retrieving result 422 for city name:Labuhan
# Retrieving result 423 for city name:Tārānagar
# Retrieving result 424 for city name:Port Lincoln
# Retrieving result 425 for city name:Nouadhibou
# Missing info
# Retrieving result 427 for city name:Korla
# Retrieving result 428 for city name:Salalah
# Retrieving result 429 for city name:Boromo
# Retrieving result 430 for city name:Río Gallegos
# Retrieving result 431 for city name:Nueve de Julio
# Retrieving result 432 for city name:Luganville
# Retrieving result 433 for city name:San Cristobal
# Retrieving result 434 for city name:Rock Sound
# Retrieving result 435 for city name:Nyzhni Sirohozy
# Retrieving result 436 for city name:Porto-Novo
# Retrieving result 437 for city name:Río Tercero
# Retrieving result 438 for city name:Yuancheng
# Retrieving result 439 for city name:Shar
# Retrieving result 440 for city name:Takaungu
# Retrieving result 441 for city name:Birnin Kebbi
# Retrieving result 442 for city name:Flin Flon
# Missing info
# Retrieving result 444 for city name:Kieta
# Retrieving result 445 for city name:Maun
# Retrieving result 446 for city name:Iwanai
# Retrieving result 447 for city name:Panguna
# Retrieving result 448 for city name:Andra
# Missing info
# Retrieving result 450 for city name:San Ramon
# Retrieving result 451 for city name:Pontal do Paraná
# Retrieving result 452 for city name:Akita
# Retrieving result 453 for city name:Dakar
# Retrieving result 454 for city name:Southbridge
# Retrieving result 455 for city name:Parkersburg
# Missing info
# Retrieving result 457 for city name:Mackay
# Retrieving result 458 for city name:Yellowknife
# Retrieving result 459 for city name:Itaituba
# Retrieving result 460 for city name:Nantucket
# Retrieving result 461 for city name:Hasaki
# Retrieving result 462 for city name:Caçapava do Sul
# Retrieving result 463 for city name:Flinders
# Missing info
# Retrieving result 465 for city name:Abhā
# Retrieving result 466 for city name:Itaú de Minas
# Retrieving result 467 for city name:Likhoslavl'
# Retrieving result 468 for city name:Port Blair
# Missing info
# Retrieving result 470 for city name:San Policarpo
# Retrieving result 471 for city name:Turaif
# Retrieving result 472 for city name:Vysokogornyy
# Retrieving result 473 for city name:Eilat
# Retrieving result 474 for city name:Elsterwerda
# Retrieving result 475 for city name:Sayula
# Retrieving result 476 for city name:Dale
# Retrieving result 477 for city name:Sept-Îles
# Retrieving result 478 for city name:Vila Velha
# Retrieving result 479 for city name:Yulara
# Retrieving result 480 for city name:Qasigiannguit
# Retrieving result 481 for city name:Russell
# Retrieving result 482 for city name:Yuci
# Retrieving result 483 for city name:La Peca
# Retrieving result 484 for city name:Eufaula
# Retrieving result 485 for city name:Batticaloa
# Retrieving result 486 for city name:Zhanakorgan
# Retrieving result 487 for city name:Todos Santos
# Retrieving result 488 for city name:Rafsanjān
# Retrieving result 489 for city name:Tonota
# Retrieving result 490 for city name:Outjo
# Retrieving result 491 for city name:Borborema
# Retrieving result 492 for city name:Tarnogskiy Gorodok
# Retrieving result 493 for city name:Payo
# Retrieving result 494 for city name:Coquimbo
# Retrieving result 495 for city name:Kormilovka
# Retrieving result 496 for city name:Kankaanpää
# Retrieving result 497 for city name:Ulladulla
# Retrieving result 498 for city name:Shache
# Retrieving result 499 for city name:Algiers
# Retrieving result 500 for city name:El Vigia
# Retrieving result 501 for city name:Petropavlovsk-Kamchatskiy
# Retrieving result 502 for city name:Hede
# Missing info
# Retrieving result 504 for city name:Ürümqi
# Retrieving result 505 for city name:Port Hardy
# Retrieving result 506 for city name:Batagay-Alyta
# Retrieving result 507 for city name:Maamba
# Retrieving result 508 for city name:Aksu
# Retrieving result 509 for city name:Rio Grande
# Missing info
# Retrieving result 511 for city name:Tevaitoa
# Retrieving result 512 for city name:Changji
# Retrieving result 513 for city name:Orissaare
# Retrieving result 514 for city name:Nioki
# Retrieving result 515 for city name:Oddur
# Retrieving result 516 for city name:Octeville
# Retrieving result 517 for city name:Agirish
# Missing info
# Retrieving result 519 for city name:Khabarovsk
# Retrieving result 520 for city name:Abu Dhabi
# Retrieving result 521 for city name:São Filipe
# Retrieving result 522 for city name:Tilichiki
# Missing info
# Retrieving result 524 for city name:Lubango
# Retrieving result 525 for city name:Port-Gentil
# Retrieving result 526 for city name:Ténenkou
# Retrieving result 527 for city name:Ihosy
# Retrieving result 528 for city name:Trincomalee
# Missing info
# Retrieving result 530 for city name:Vostok
# Retrieving result 531 for city name:San Patricio
# Retrieving result 532 for city name:Kamaishi
# Retrieving result 533 for city name:Pangkalanbuun
# Retrieving result 534 for city name:Mīzan Teferī
# Retrieving result 535 for city name:Walvis Bay
# Retrieving result 536 for city name:Barão de Melgaço
# Retrieving result 537 for city name:San Angelo
# Retrieving result 538 for city name:Gao
# Retrieving result 539 for city name:Sechura
# Retrieving result 540 for city name:Antofagasta
# Missing info
# Missing info
# Retrieving result 543 for city name:Rawson
# Missing info
# Retrieving result 545 for city name:Celestún
# Retrieving result 546 for city name:Sakakah
# Retrieving result 547 for city name:Calama
# Retrieving result 548 for city name:Quatre Cocos
# Retrieving result 549 for city name:Alekseyevka
# Retrieving result 550 for city name:Buchanan
# Retrieving result 551 for city name:Mandalgovi
# Missing info
# Retrieving result 553 for city name:Sola
# Retrieving result 554 for city name:Avera
# Retrieving result 555 for city name:Luleå
# Retrieving result 556 for city name:Saint-Joseph
# Retrieving result 557 for city name:Asău
# Retrieving result 558 for city name:Matara
# Retrieving result 559 for city name:Castlemaine
# Retrieving result 560 for city name:São João da Barra
# Retrieving result 561 for city name:Tabas
# Retrieving result 562 for city name:Cayenne
# Retrieving result 563 for city name:Lagoa
# Retrieving result 564 for city name:Kanye
# Missing info
# Retrieving result 566 for city name:Santa Barbara
# Retrieving result 567 for city name:Seymchan
# Retrieving result 568 for city name:Rognan
# Retrieving result 569 for city name:Harindānga
# Retrieving result 570 for city name:Perth
# Retrieving result 571 for city name:Arrondissement de Fontenay-le-Comte
# Retrieving result 572 for city name:Coyhaique
# Retrieving result 573 for city name:Pinehurst
# Retrieving result 574 for city name:Aktash
# Retrieving result 575 for city name:Grand Gaube
# Retrieving result 576 for city name:Luanda
# Retrieving result 577 for city name:Angoram
# Retrieving result 578 for city name:Marzuq
# Retrieving result 579 for city name:Khovd
# Retrieving result 580 for city name:Ossora
# Missing info
# Retrieving result 582 for city name:Qandala
# Retrieving result 583 for city name:Pacific Grove
# Retrieving result 584 for city name:Lázaro Cárdenas
# Retrieving result 585 for city name:Cruzeiro do Sul
# Retrieving result 586 for city name:Laas
# Missing info
# Retrieving result 588 for city name:Udachny
# Retrieving result 589 for city name:Yermekeyevo
# Retrieving result 590 for city name:Bathsheba
# Retrieving result 591 for city name:Kirensk
# Retrieving result 592 for city name:Corowa
# Retrieving result 593 for city name:Tiznit Province
# Retrieving result 594 for city name:Cairns
# Retrieving result 595 for city name:Valdemārpils
# Retrieving result 596 for city name:Salym
# Retrieving result 597 for city name:Puerto Escondido
# Retrieving result 598 for city name:Arlit
# Retrieving result 599 for city name:Ambilobe
# Retrieving result 600 for city name:Hofn
# Retrieving result 601 for city name:Siátista
# Retrieving result 602 for city name:Elko
# Retrieving result 603 for city name:Palu
# Retrieving result 604 for city name:Sompeta
# Retrieving result 605 for city name:Vágur
# Retrieving result 606 for city name:Khyriv
# Retrieving result 607 for city name:Hūn
# Retrieving result 608 for city name:Paamiut
# Missing info

# %%
#test_cities_df = test_cities_df.iloc[0:0]
final_cities_df = cities_df.reset_index(drop=True)
final_cities_df.head(10)
# Out:
#                City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0       Kloulklubed   7.04  134.26     84.2       79         75      10.29
# 1         Busselton -33.65  115.33       54       61         13       8.05
# 2          Namangan     41   71.67       50       76         13        4.7
# 3           Rikitea -23.12 -134.97    76.37       75         24      12.77
# 4        Bredasdorp -34.53   20.04       59       94        100       0.36
# 5            Albany   42.6  -73.97       41       30         40      17.22
# 6    Saint-Philippe -21.36   55.77     75.2       69         19      13.87
# 7  Muroto-misakicho  33.28  134.15     57.2       67         75        4.7
# 8      Norman Wells  65.28 -126.83     44.6       81         75      12.75
# 9         Cape Town -33.93   18.42       59       93         86        4.7
#
#   Country
# 0      PW
# 1      AU
# 2      UZ
# 3      PF
# 4      ZA
# 5      US
# 6      RE
# 7      JP
# 8      CA
# 9      ZA

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
final_cities_df.to_csv('Output/Cities_Weather.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_weather = final_cities_df.copy()


over_humidity = cities_weather.loc[cities_weather['Humidity'] > 100, : ]
over_humidity
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

#n/a

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#n/a

# %%
# Extract relevant fields from the data frame

#n/a

# Export the City_Data into a csv

#n/a

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cities_weather.info()

cities_weather_df = cities_weather.astype({'Lat': float, 'Lng': float, 'Max Temp': float})

cities_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 8 columns):
# City          557 non-null object
# Lat           557 non-null object
# Lng           557 non-null object
# Max Temp      557 non-null object
# Humidity      557 non-null object
# Cloudiness    557 non-null object
# Wind Speed    557 non-null object
# Country       557 non-null object
# dtypes: object(8)
# memory usage: 34.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 8 columns):
# City          557 non-null object
# Lat           557 non-null float64
# Lng           557 non-null float64
# Max Temp      557 non-null float64
# Humidity      557 non-null object
# Cloudiness    557 non-null object
# Wind Speed    557 non-null object
# Country       557 non-null object
# dtypes: float64(3), object(5)
# memory usage: 34.9+ KB

# %%
cities_weather_df.plot(kind='scatter', x='Lat', y='Max Temp', grid=True)

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (4/16/20)')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
